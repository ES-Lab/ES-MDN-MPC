# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from modules.solar import PVdata
from modules.economy import ElecPrice

pv_data_path = './data/timeseries-slimpark-2022.csv'
price_data_path='./data/day_ahead_prices_2022.csv'
PV_panel = PVdata(pv_data_path)
elec_price = ElecPrice(price_data_path)

# %%
PV_panel.next_day()
plt.plot(PV_panel.day_data, label='PV Output')
plt.plot(PV_panel.forecast, label='Forecast')
plt.plot(PV_panel.merge_forecasst(60), label='Merged')

plt.legend()

# %%
len(PV_panel.resampled_data['solar_measurement'])/96
# Out:
# 165.0
